# %% [markdown]
# #### Filter

# %%
def check(num):
    if num%2==0:
        return True
lst=range(10)
list(filter(check,lst))
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# #### Counter

# %%
from collections import Counter
print(Counter([5,6,8,4,7,5,9,6,2,1,3,5,8]))
# Out:
# Counter({5: 3, 6: 2, 8: 2, 4: 1, 7: 1, 9: 1, 2: 1, 1: 1, 3: 1})

# %%
print(Counter('sdasdasdadasdasda'))  # String
# Out:
# Counter({'d': 6, 'a': 6, 's': 5})

# %%
print(Counter([1.2,3.2,1.2,3]))
# Out:
# Counter({1.2: 2, 3.2: 1, 3: 1})

# %%
print(Counter([1,2,3,'hasdh']))
# Out:
# Counter({1: 1, 2: 1, 3: 1, 'hasdh': 1})

# %% [markdown]
# #### Regular expression

# %%
import re
patt = r'\d{2}-\d{2}-\d{4}'
message="His birthday is 16-11-2016"
re.findall(patt,message)
# Out:
# ['16-11-2016']

# %% [markdown]
# #### Working with files

# %%
f=open("welcome.txt","r")
print(f.read())
f.close()
# Out:
# Hello All
# welcome to python Bootcamp
# nice to see you all

# %%
f=open("welcome.txt","r")
print(f.read(5))
f.close()
# Out:
# Hello

# %%
f=open("welcome.txt","r")
print(f.readline())
f.close()
# Out:
# Hello All

# %%
f=open("welcome.txt","r")
for x in f:
    print(x)
# Out:
# Hello All
#
# welcome to python Bootcamp
#
# nice to see you all

# %% [markdown]
# #### File Handling Using Pandas

# %%
import pandas as pd
data=pd.read_csv('data_p.csv')
print(data.to_string())
# Out:
#     Age  Salary  Status
# 0    18   82000       0
# 1    29   80000       0
# 2    47   25000       1
# 3    45   26000       1
# 4    46   28000       1
# 5    48   29000       1
# 6    45   22000       1
# 7    47   49000       1
# 8    48   41000       1
# 9    45   22000       1
# 10   46   23000       1
# 11   47   30000       1

# %%
import pandas as pd
data = pd.read_csv('data_p.csv')
print(data.shape)
print(data.describe())
print(data.head(5))
# Out:
# (12, 3)
#              Age        Salary     Status
# count  12.000000     12.000000  12.000000
# mean   42.583333  38083.333333   0.833333
# std     9.278110  21584.751913   0.389249
# min    18.000000  22000.000000   0.000000
# 25%    45.000000  24500.000000   1.000000
# 50%    46.000000  28500.000000   1.000000
# 75%    47.000000  43000.000000   1.000000
# max    48.000000  82000.000000   1.000000
#    Age  Salary  Status
# 0   18   82000       0
# 1   29   80000       0
# 2   47   25000       1
# 3   45   26000       1
# 4   46   28000       1

# %% [markdown]
# #### Working with Directories

# %%
import os
print(os.getcwd())
print(os.listdir())
os.mkdir("Junck")
# Out:
# C:\Users\hp
# ...

# %%
import shutil
shutil.move('C:/Users/hp/welcome.txt','C:/Users/hp/Junck')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     790     try:
# --> 791         os.rename(src, real_dst)
#     792     except OSError:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:/Users/hp/welcome.txt' -> 'C:/Users/hp/Junck\\welcome.txt'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-37-18f5874cf09c> in <module>
#       1 import shutil
# ----> 2 shutil.move('C:/Users/hp/welcome.txt','C:/Users/hp/Junck')
#
# C:\ProgramData\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     804         else:
#     805             copy_function(src, real_dst)
# --> 806             os.unlink(src)
# ...

# %%
# importing shutil module 
import shutil 
  
source = "C:/Users/hp/welcome.txt"
destination ="C:/Users/hp/Junck"
  
# Copy the content of 
# source to destination 
dest = shutil.copy(source, destination)

# %%
import send2trash
os.listdir()
send2trash.send2trash('C:/Users/hp/Junck/welcome.txt')

# %% [markdown]
# #### Time

# %%
import time
print(time.time())  #time since epoch
# Out:
# 1646850211.021337

# %%
print(time.gmtime())
# Out:
# time.struct_time(tm_year=2022, tm_mon=3, tm_mday=9, tm_hour=18, tm_min=25, tm_sec=44, tm_wday=2, tm_yday=68, tm_isdst=0)

# %%
print(time.ctime())
# Out:
# Wed Mar  9 23:56:02 2022

# %%
startTime =time.time()
i=0
while(i<5):
    i+=1
    time.sleep(1) #delay 1 second
    print(".")
    time.sleep(1)
stopTime =time.time()
diff =stopTime - startTime
diff
# Out:
# .
# .
# .
# .
# .
# 10.051236391067505

# %% [markdown]
# #### Date & Time

# %%
import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2022-03-10 00:12:22.355861

# %%
import datetime
a = datetime.datetime(2021, 3, 15)   #(year,month,date,hour,minitue,second,macros)
print(a.strftime("%B"))
# Out:
# March

# %%
import datetime
a = datetime.datetime(2021, 3, 15)   #(year,month,date,hour,minitue,second,macros)
print(a.strftime("%a"))
# Out:
# Mon

# %% [markdown]
# ### Web Scraping with Python | weather Data from Google

# %% [markdown]
# * Web scraping is the process of collecting and parsing raw data from the Web.
# * You are going to access the data from web
# * You are going to clean the raw data with the help of python programming and its libraries.
#
# Simply create a python script which extracts weather data from Google.
# we need to install two modules
#
# Requirements:-
#
# 1. requests - https://pypi.org/project/requests/
#
#    pip install requests
#
#
# 2. beautifulsoup4 - https://pypi.org/project/beautifulsoup4/
#
#    pip install beautifulsoup4
#
#
#  Steps:
#
#  1. Import the module
#  2. Enter the city name with the URL
#  3. Make requests instance and pass the URL
#  4. Get the raw data
#  5. Extract the required data from soup
#  6. Finally print the required data.

# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# ...

# %%
# !pip install bs4
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=ad4183a0d04fc589b0e7fdf1584a7f2a2989c829a8657a0515a16482594464cf
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...

# %%
# !pip install html
# !pip install lxml
# Out:
# ...
#   Created wheel for html: filename=html-1.13-py3-none-any.whl size=8776 sha256=59701f9aafb34f3e9ff7b1316829eb250793eecd896e21a83f3d056ddeb626da
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\c0\21\ad\203945982748e554f20c4076c157e73186bf4e7adb6a775e6e
# Successfully built html
# ...
#     ERROR: Command errored out with exit status 1:
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
#taking input from user
city=str(input("Enter City name "))

#creating URL
url="https://www.google.com/search?q="+"weather"+city
# Out:
# Enter City name delhi

# %%
#requests instance
html=requests.get(url).content

# %%
#getting the raw data

soup = BeautifulSoup(html,'html.parser')

# %%
#getting the temperature

temp=soup.find('div',attrs={'class':'BNeawe iBp4i AP7Wnd'}).text

# %%
#getting the time and sky description
time_skyDescription=soup.find('div',attrs={'class':'BNeawe tAd8D AP7Wnd'}).text

# %%
# formatting the data
data = time_skyDescription.split('\n')
time = data[0]
sky = data[1]

# %%
# list which is having all div tags with particular class names

listdiv = soup.findAll('div',attrs={'class':'BNeawe s3v9rd AP7Wnd'})

# %%
# the data we need is avaiable at index 5

strd=listdiv[5].text

# %%
#formatting the string
pos = strd.find('wind')
otherData = strd[pos:]

# %%
#printing the data we need

print("Temperature is",temp)
print("Time: ",time)
print("sky Description : ",sky)
print(otherData)
# Out:
# Temperature is 33°C
# Time:  Monday 3:51 pm
# sky Description :  Sunny
# ,

# %% [markdown]
# # Example : 2 Extracting information from flipkart

# %%
import requests
url ="https://www.flipkart.com/canon-eos-1500d-dslr-camera-body-18-55-mm-ii-lens/p/itm033175ceb4ddd?pid=DLLFAEWE22ZAERXG&lid=LSTDLLFAEWE22ZAERXGAHOJFJ&marketplace=FLIPKART&store=jek%2Fp31%2Ftrv&srno=b_1_1&otracker=browse&fm=organic&iid=910051f1-fb65-4f47-be86-6c50836921db.DLLFAEWE22ZAERXG.SEARCH&ppt=browse&ppn=browse"

response =requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6c22a8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
#putting this response content in a variable

htmlcontent=response.content

# %%
print(htmlcontent)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6c22a8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("htmlcontent")
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    htmlcontent
#   </p>
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("htmlcontent",'html.parser')
print(soup.prettify())
# Out:
# htmlcontent

# %%
#Example:3
import requests
from bs4 import BeautifulSoup
import sys
import time

# %%
page=requests.get('https://www.cricbuzz.com/')
soup=BeautifulSoup(page.text,'html.parser')

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#links=soup.find_all('div',attr={'class':"cb-nws-time"})
links=soup.find('div',attrs={'div',attrs={'class':'cb-nws-time'}}).text
# Out:
#   File "<ipython-input-130-37f43206d72a>", line 2
#     links=soup.find('div',attrs={'div',attrs={'class':'cb-nws-time'}}).text
#                                             ^
# SyntaxError: invalid syntax

# %%
links=soup.find('div',attrs={'class':'cb-nws-intr'}).text

# %%
links
# Out:
# 'India struck at regular intervals after declaring with a lead of 446'

# %%
links = soup.findAll('div',attrs={'class':'cb-nws-intr'})

# %%
links
# Out:
# [<div class="cb-nws-intr">India struck at regular intervals after declaring with a lead of 446</div>,
#  <div class="cb-nws-intr">Earlier in the day, Australia declared their innings on 556</div>,
#  <div class="cb-nws-intr">Kapp got her maiden five-fer and then struck 32 in South Africa's third win in the World Cup 2022</div>,
#  <div class="cb-nws-intr">Javeria Khan started her international career as an offspinner but has become Pakistan's most prolific ODI batter. She explains how a simple love for the game allowed her to have success in an unexpected discipline, and how she keeps improving.</div>,
#  <div class="cb-nws-intr">Although a docile pitch and some excellent batting from Bonner and Holder prevented England from forcing a win, just the mere fact that they went for it was a welcome development</div>,
#  <div class="cb-nws-intr">The former South Africa skipper will become the seventh to lead Royal Challengers Bangalore</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# India struck at regular intervals after declaring with a lead of 446
#
#
# Earlier in the day, Australia declared their innings on 556
#
#
# Kapp got her maiden five-fer and then struck 32 in South Africa's third win in the World Cup 2022
#
#
# Javeria Khan started her international career as an offspinner but has become Pakistan's most prolific ODI batter. She explains how a simple love for the game allowed her to have success in an unexpected discipline, and how she keeps improving.
#
#
# Although a docile pitch and some excellent batting from Bonner and Holder prevented England from forcing a win, just the mere fact that they went for it was a welcome development
#
#
# The former South Africa skipper will become the seventh to lead Royal Challengers Bangalore
#
#
# The team's selection choices need a rethink, writes former India coach WV Raman
#
#
# There is a line of thinking in the BCCI that the ICC chairman post should come to India given that it is hosting the tournament
#
#
# ...
